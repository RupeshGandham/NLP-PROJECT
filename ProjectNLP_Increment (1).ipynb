# %%
# !pip install tweepy==4.10.1 
# !pip show tweepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tweepy==4.10.1
#   Downloading tweepy-4.10.1-py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 KB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.27.0 in /usr/local/lib/python3.9/dist-packages (from tweepy==4.10.1) (2.27.1)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from tweepy==4.10.1) (1.3.1)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from tweepy==4.10.1) (3.2.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.27.0->tweepy==4.10.1) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.27.0->tweepy==4.10.1) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.27.0->tweepy==4.10.1) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.27.0->tweepy==4.10.1) (3.4)
# Installing collected packages: tweepy
#   Attempting uninstall: tweepy
#     Found existing installation: tweepy 4.13.0
#     Uninstalling tweepy-4.13.0:
#       Successfully uninstalled tweepy-4.13.0
# Successfully installed tweepy-4.10.1
# Name: tweepy
# Version: 4.10.1
# Summary: Twitter library for Python
# Home-page: https://www.tweepy.org/
# Author: Joshua Roesslein
# Author-email: tweepy@googlegroups.com
# License: MIT
# Location: /usr/local/lib/python3.9/dist-packages
# Requires: oauthlib, requests, requests-oauthlib
# Required-by:

# %%
import os
import tweepy as twep
import pandas as pd

# %%
#keys that are used to access the twitter API
consumer_key= 'Y3RJeJFRHnA9QnpZu8z9S0Skb'
consumer_secret= 'mSHz1KdYkTNmYWuxMwX4fMzzGc9qv1OqgyQxWU26pheoGRcLuE'
access_token= '1287803472805367808-EedGVpYxgeXKILni2gt9HvJacgsmxx'
access_token_secret= 'K9jXNXr6i72odGz9XAiUnN5841eIUiDKcrj52RozRO743'

# %%
#Code to access the api and authentication to connect to twitter API
auth = twep.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = twep.API(auth, wait_on_rate_limit=True)

# %%
#code for searching the Tweets with keyword Google and add them to a text file twitter.txt
keyword = 'Google'
limit=1000
tweets = twep.Cursor(api.search_tweets, q=keyword, tweet_mode='extended').items(limit)
file = open('twitter.txt', 'w', encoding="utf-8")
for tweet in tweets:
    file.write(tweet.full_text+'\n')
file.close()

# %%
#code for searching the Tweets with keyword #GOOGLE and add them to a text file twitter.txt
keyword = '#GOOGLE'
limit=1000
tweets = twep.Cursor(api.search_tweets, q=keyword, tweet_mode='extended').items(limit)
file = open('twitter.txt', 'a', encoding="utf-8")
for tweet in tweets:
    file.write(tweet.full_text+'\n')
file.close()

# %%
#code for searching the Tweets with keyword Google and Tesla and add them to a text file twitter.txt
keyword = 'google and Tesla'
limit=1000
tweets = twep.Cursor(api.search_tweets, q=keyword, tweet_mode='extended').items(limit)
file = open('twitter.txt', 'a', encoding="utf-8")
for tweet in tweets:
    file.write(tweet.full_text+'\n')
file.close()

# %%
#opening file to write the processed text
file = open('processed.txt', 'w', encoding="utf-8")

# %%
#preprocessing
import re
with open('twitter.txt','r', encoding="utf-8") as f:
    lines = f.readlines()
f.close()
for line in lines:
    content=' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", line).split())
    file.write(content+'.'+'\n')
file.close()

# %%
#Converting the input file into the list of sentences. 
Input = open("processed.txt", "r")
data = Input.read()
data_to_list = data.split("\n")
Input.close()

# %%
#Adding the input text that needs to be classified to the TEST variable
Test_X=[]
for x in data_to_list:
    Test_X.append(x)
Test_X
# Out:
# ['RT.',
#  '2023.',
#  'RT.',
#  'Google Pixel Watch.',
#  'Belkin.',
#  'Logicool.',
#  '5.',
#  '.',
#  '.',
#  '.',
#  'RT idowhatilove.',
#  '.',
#  'This is Winny and this is WINNY.',
#  '.',
#  '.',
#  'thanawin winynny https.',
#  'RT org Grandma Factory s presale starts on April 14.',
#  '.',
#  'They are building NFTs backed by exceptional luxury collectible a.',
#  'RT Google During Hanukkah.',
#  '.',
#  'Google During Ramadan.',
#  '.',
#  'Google During Transgender Day of Visibility.',
#  '.',
#  'Google During Easter Sunday.',
#  'RT fc set.',
#  '.',
#  '.',
#  '2.',
#  '1 55.',
#  '2.',
#  'Subtler dimension trouble When you hear is the challenge at all.',
#  'use this.',
#  'bath and body onass NOON promo NON TOYOU To you COUPON SIVVI NAMSHI CODE OUNAS discount OUNASS.',
#  'Rolled on about Google.',
#  'RT N o se engane O globalismo socialista e seus aparelhos enxergam com raz o o Cristianismo como inimigo.',
#  '.',
#  'O Google tem.',
#  'RT hw 1177 SBS.',
#  '2023 04 09 16 38 04 12 18 00.',
#  '.',
#  'SuperStar X gt gt.',
#  'Android.',
#  'RT A career performance from dunk champion Mac McClung led the to the W in Brooklyn They ll face off again in Round 1 of the.',
#  '26 Number Web.',
#  'RT 6 more days to get a dinotter photocard holder.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'DINO htt.',
#  'RT 5.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'RT.',
#  '2023.',
#  'RT.',
#  'Google Pixel Watch.',
#  'Belkin.',
#  'Logicool.',
#  '5.',
#  '.',
#  '.',
#  '.',
#  'RT Sant Shri Asharamji Bapu.',
#  'Turning Point.',
#  'RT.',
#  '2023.',
#  'RT.',
#  'Google Pixel Watch.',
#  'Belkin.',
#  'Logicool.',
#  '5.',
#  '.',
#  '.',
#  '.',
#  'ChatGPT Google Spred Sheets Exceeded maximum execution time 30 API.',
#  'RT BitMart X PRMX Airdrop.',
#  '234 850 000 PRMX.',
#  '.',
#  '1 Follow amp amp en.',
#  '2 Join https.',
#  'RT festival T.',
#  '.',
#  '.',
#  'T 1 3000.',
#  'T 5000.',
#  'White or Light pink.',
#  'M XXXL.',
#  'XXL 300 XXL 500.',
#  '.',
#  '.',
#  'RT pls rt 1.',
#  'PREORDER LISA 0327 PHOTOBOOK VOL 4.',
#  '.',
#  'Benefit YG Select.',
#  '1 190.',
#  '.',
#  'RT.',
#  'Against War.',
#  '.',
#  '3.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'RT.',
#  '.',
#  '10.',
#  '1000.',
#  '.',
#  'Googlepl.',
#  '.',
#  'Gmail Gmail Google.',
#  '.',
#  '.',
#  '10.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'WATA.',
#  'RT Wish upon your STAR and your wish might just come true P1ece Submit any of your wishes that you d like off.',
#  'No entend s de lo que est s hablando.',
#  '.',
#  'Al menos podr as usar Google antes de escribir tan confiado tremenda burrada.',
#  '.',
#  'Google My Maps.',
#  '.',
#  'RT Google Pixel DIO.',
#  'RT ver.',
#  '.',
#  '.',
#  'Honeys.',
#  '.',
#  'RT Google During Hanukkah.',
#  '.',
#  'Google During Ramadan.',
#  '.',
#  'Google During Transgender Day of Visibility.',
#  '.',
#  'Google During Easter Sunday.',
#  'RT BitMart X PRMX Airdrop.',
#  '234 850 000 PRMX.',
#  '.',
#  '1 Follow amp amp en.',
#  '2 Join https.',
#  'Ai vc me pergunta como eu compro pasta de dente aqui no Jap o.',
#  '.',
#  'Eu compro 4 cremes dentais diferentes e intercalo o uso deles.',
#  '.',
#  'Poderia usar o Google tradutor.',
#  'Claro que sim.',
#  'M s s se vive uma vez.',
#  'RT Wallpaper giveaway.',
#  '.',
#  'pls rt.',
#  'link download.',
#  '.',
#  '.',
#  'Do not repropose do not use commercia.',
#  's lo s en google lens te sirve igual.',
#  'RT Calling writers literary agents amp publishers.',
#  'We are looking for potential books to be launched at GTLF2023.',
#  '.',
#  'Submi.',
#  'RT Wayne Apa ada yang bisa bantu isi kuisioner ada gopay 30k bagi yang beruntung.',
#  '.',
#  'Syarat retweet dan isi link.',
#  '.',
#  'RT SVT FML.',
#  '.',
#  'SEVENTEEN 17 Coming back in April 24th at 6PM with 10th mini album FML first double title song.',
#  'RT Could someone please translate this to English I think Google is translating it wrong and I m not fluent in Spanish just.',
#  'RT RT 500.',
#  '.',
#  'NCT DOJAEJUNG Perfume photobook ver.',
#  '.',
#  '250.',
#  '130.',
#  '.',
#  'RT if you google spotify filtering rate you will straight up get articles about them being unfair towards bts AND NOT ANYTHING E.',
#  'He literally walked in a teenage pageant dressing room while they were dressing and bragged about it.',
#  '.',
#  'Ffs.',
#  '.',
#  '.',
#  'RT Hey yo CHAERISH.',
#  'I m doing a flash project.',
#  'Just need your few minutes to send your message to the beloved Feather.',
#  'Let s.',
#  'RT Thailand UpSize Starry Member.',
#  '.',
#  'RT 14.',
#  '.',
#  '.',
#  '.',
#  'PEACE MAKER.',
#  'RT 500 7 Days.',
#  '.',
#  '200.',
#  'RT amp Follow RT.',
#  '.',
#  '200.',
#  'Join Both Post Proof.',
#  '.',
#  'ht.',
#  'RT HILO DE COMO VOTAR POR ENHYPEN EN FANNSTAR.',
#  '.',
#  'Links para descargar la aplicaci n.',
#  'IOS.',
#  'android.',
#  'RT Avoid the area and take alternative routes.',
#  '.',
#  'N4.',
#  '.',
#  'BRUSH FIRE ON RS.',
#  'Region Santa Fe Springs CAfire.',
#  'RT This is 9 weeks Ted You really should Google these things before making a completely thoughtless ghoul of yourself http.',
#  'RT Dear Doctor we re honored to present you the Top 20 players in Soldiers Assemble Barrage Fortress so far Don t forget t.',
#  'BRUSH FIRE.',
#  'Region Santa Fe Springs CAfire.',
#  'RT 455.',
#  '.',
#  'The Duggars A Comprehensive Guide of the Famous Family.',
#  'HOV.',
#  'Region Santa Fe Springs CAfire.',
#  'Not Real Time ALARMRF 1031 GLENDALYN CIR Spartanburg.',
#  'Municipio Alvorada RS.',
#  'Setor censit rio 430060405060015.',
#  'Popula o 883.',
#  'rea Km2 0 07.',
#  'Densidade hab Km2 12781 23.',
#  'Zona urbana.',
#  '6149.',
#  'RT post2 Google.',
#  'RT.',
#  'Against War.',
#  '.',
#  '2.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'RT.',
#  '.',
#  '10.',
#  '1000.',
#  '.',
#  'Googlepl.',
#  'RT Open Pre Order.',
#  'SEVENTEEN 10th Mini Album FML by 17.',
#  '.',
#  'Weverse Aladin Yes24 Ktown4U Yizhiyu Mukor Mupl.',
#  'RT.',
#  '2023.',
#  'RT.',
#  'Google Pixel Watch.',
#  'Belkin.',
#  'Logicool.',
#  '5.',
#  '.',
#  '.',
#  '.',
#  'google.',
#  'RT shiki.',
#  '.',
#  'QUOPay 500 or 30.',
#  '.',
#  'RT.',
#  '.',
#  '.',
#  '.',
#  'shiki.',
#  'RT.',
#  '.',
#  '1.',
#  'RT.',
#  '2023.',
#  'RT.',
#  'Google Pixel Watch.',
#  'Belkin.',
#  'Logicool.',
#  '5.',
#  '.',
#  '.',
#  '.',
#  'RT kim an.',
#  '.',
#  '20 1359.',
#  '1.',
#  'w.',
#  '.',
#  '550.',
#  '.',
#  '.',
#  '.',
#  'RT.',
#  'BAEKHYUN.',
#  '.',
#  'RT Hey ladies I m still updating the radical feminist library drive I have over 300 books amp essays uploaded amp I will continu.',
#  '4 10.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '03 6450 9023.',
#  'Google MAP.',
#  '.',
#  'risk.',
#  'RT GodMorningMonday.',
#  '.',
#  'RT RECORD13 RADIO TIME.',
#  '.',
#  'TODAY is for MONDAY Radio Request.',
#  '.',
#  '.',
#  'iHeart Like Crazy.',
#  'RT translated by google translator.',
#  '.',
#  'There is a famous Brazilian YouTuber spreading false information about BamBam We in.',
#  'RT Those who have Amazon Prime hope yall know that yall also have full access to Amazon Music It is a 100 premium streami.',
#  'RT How Google celebrates a holiday observed by 2 8 billion people.',
#  'RT TSI TSI KenkoShindan.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'RT 15.',
#  '.',
#  's s.',
#  '.',
#  '.',
#  '.',
#  'artwork Gemini NT Fourthnattawat.',
#  'RT supremacy Reply amp Retweet.',
#  '.',
#  'I vote V from BTS for TOP100KPOPMEMBERS.',
#  '.',
#  '.',
#  'GOOGLE KING BTS V.',
#  'h.',
#  'RT Could someone please translate this to English I think Google is translating it wrong and I m not fluent in Spanish just.',
#  'RT shimejiee.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'suha art htt.',
#  'RT Call for all beta testers.',
#  '.',
#  'Airdrop of Repairing Voucher 50 5 to you all NOW.',
#  '.',
#  'Let s RUN.',
#  '.',
#  'For all advan.',
#  'RT Xiao.',
#  '2023.',
#  '.',
#  '.',
#  '2023 4 9 2023 4 10.',
#  '.',
#  '.',
#  'RT 3.',
#  'RT shiki.',
#  '.',
#  'QUOPay 500 or 30.',
#  '.',
#  'RT.',
#  '.',
#  '.',
#  '.',
#  'shiki.',
#  'RT.',
#  '.',
#  '1.',
#  'RT.',
#  '2023.',
#  'RT.',
#  'Google Pixel Watch.',
#  'Belkin.',
#  'Logicool.',
#  '5.',
#  '.',
#  '.',
#  '.',
#  'RT.',
#  'VS.',
#  '.',
#  'GodMorningSaturday.',
#  'FactsAboutJesus.',
#  'To know Download our O.',
#  'RT AROHA DALKONGS Y SANPS Es hora de elegir las frases para el banner que alzaremos para Binsan y hagamos de este un momento.',
#  'VS.',
#  'JABA 2023.',
#  '.',
#  '.',
#  'RT restaurant bot Aspava Restaurant amp Bar 4WGV 637 Liman Yolu Sk Gazima usa 99450.',
#  'c mo saber que soy bruja hereditaria google buscar respuestas.',
#  'RT Vamos a dejar un hilo largu simo con datos para charlar durante este a o con quienes est n quemados por los medios heg.',
#  'RT family BelucaOffGunProject.',
#  'Donation Drive Update.',
#  '.',
#  'As of 09 04 2023 10 00PM.',
#  '53 716 14 120 00.',
#  '.',
#  '.',
#  '.',
#  'For Donate https.',
#  'RT mini comic de los esposos t xicos us google translate ok.',
#  '.',
#  'fliporiana slimeriana.',
#  'RT 8 A friend of mine is organising this event Engineering enthusiasts please make use of this opportunity and get benefited.',
#  'RT According AFU estimations RF lost 1 1 8 4 2023.',
#  '.',
#  '607 tanks 3029 to 3636 949 APV s 60.',
#  'RT This is 9 weeks Ted You really should Google these things before making a completely thoughtless ghoul of yourself http.',
#  'RT Not gonna lie I had to google Napoleon letters to Josephine tonight worth every penny then.',
#  '.',
#  'GODDAMN.',
#  'RT BitMart X PRMX Airdrop.',
#  '234 850 000 PRMX.',
#  '.',
#  '1 Follow amp amp en.',
#  '2 Join https.',
#  'KU.',
#  '.',
#  '.',
#  '29 66.',
#  '.',
#  '1.',
#  '.',
#  'csdsdku KU.',
#  'SDKU.',
#  'RT shop RT 3.',
#  'PRE JISOO TAG ALBUM LP Ver.',
#  '.',
#  '.',
#  'Ktown4u Weverse amp YG.',
#  '260 350.',
#  '.',
#  'RT PTVFLIX is here Relive your childhood with classic Pakistani tv shows.',
#  'From the iconic dramas of the 60s amp 90s to nos.',
#  'RT People assume writers have an amazing vocabulary but really we Google basic words.',
#  'RT fml giveaway.',
#  '.',
#  '1 random sealed fml album.',
#  '.',
#  'retweet and like.',
#  'ends on april 24.',
#  '.',
#  '.',
#  'RT Pls rt.',
#  '.',
#  'GOT7 PICNIC DREAMS.',
#  '.',
#  '.',
#  '.',
#  'RT org Grandma Factory s presale starts on April 14.',
#  '.',
#  'They are building NFTs backed by exceptional luxury collectible a.',
#  'RT ROS is nominated as Fan Choice of the Year at the 33rd Seoul Music Award.',
#  '.',
#  'Start casting your votes on IdolChamp and Fa.',
#  'RT.',
#  '2023.',
#  'RT.',
#  '.',
#  '.',
#  'Google Pixel Watch.',
#  'Belkin.',
#  'Logicool.',
#  '5.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'Hey Siri what is google.',
#  'RT Colabo.',
#  '.',
#  '.',
#  '.',
#  'RT emilio Apuestan a que no pueda presentarme en el juicio para que mi familia salga de donde viven ya que me encuentro detenido.',
#  'RT 5 14 hako gallary 2 2sides II at hako gallery.',
#  '.',
#  'RT burukuri.',
#  '12 1000.',
#  '2.',
#  '.',
#  '.',
#  'burukuri.',
#  '.',
#  '4 15.',
#  '.',
#  'DL.',
#  'RT The first 20 orders of my WECHINDA PROJECT set will get these DIFFUSIONinMNL photocards.',
#  '.',
#  'The photos of MOONBIN SANHA used.',
#  'RT hw 1177 SBS.',
#  '2023 04 09 16 38 04 12 18 00.',
#  '.',
#  'SuperStar X gt gt.',
#  'Android.',
#  'RT PART 2.',
#  'Fan Project for Thailand Tour.',
#  '.',
#  'Submit your audio to be included in our fan project.',
#  '.',
#  'Deadline 15 April 2023.',
#  'who is this scary lady.',
#  'should I google.',
#  'RT.',
#  '.',
#  'YouTube.',
#  '.',
#  '.',
#  'app AppStore.',
#  'RT Block B s 12th Anniversary hashtag suggesting.',
#  '.',
#  'Block B s 12th anniversary is coming soon we will start taking suggest.',
#  'Kl google translatenya gini.',
#  'RT.',
#  'RT.',
#  '.',
#  '20 000.',
#  '1.',
#  '.',
#  'PayPay Amazon iTunes Google PlayStation.',
#  '.',
#  '.',
#  'by akira.',
#  '.',
#  'Honda VS JFE.',
#  'JABA 2023.',
#  '.',
#  '.',
#  'Starts And Ends by Hillsong United People.',
#  '.',
#  'RADIO for Smartphones keep listening.',
#  'RT Google Cloud is giving no cost access to all GCP learning materials and certification vouchers.',
#  '.',
#  '.',
#  '.',
#  'GoogleCloudCert.',
#  'RT Thailand UpSize Starry Member.',
#  'torori Google.',
#  '.',
#  '.',
#  'RT jp.',
#  '.',
#  'Love Letter.',
#  '.',
#  '.',
#  '.',
#  'jp.',
#  '.',
#  '.',
#  '.',
#  'RT Could someone please translate this to English I think Google is translating it wrong and I m not fluent in Spanish just.',
#  'So lonely and looking out for older women for love someone I can rely on and give 100 percent attention Dm me on Google chat com.',
#  'RT.',
#  '2023.',
#  'RT.',
#  'Google Pixel Watch.',
#  'Belkin.',
#  'Logicool.',
#  '5.',
#  '.',
#  '.',
#  '.',
#  'RT shiki.',
#  '.',
#  'QUOPay 500 or 30.',
#  '.',
#  'RT.',
#  '.',
#  '.',
#  '.',
#  'shiki.',
#  'RT.',
#  '.',
#  '1.',
#  'RT OFFICIAL BLACKPINK THE GAME.',
#  'Styling.',
#  '.',
#  'Hey you look cute today.',
#  'You too.',
#  '.',
#  'Dressing up in BLACKPINK THE GAME.',
#  '.',
#  'Pre reg.',
#  'RT Could someone please translate this to English I think Google is translating it wrong and I m not fluent in Spanish just.',
#  'RT Google translated In summary a minor 16 yr old was sued by a BYL and found guilty of.',
#  'defamation She will be detai.',
#  'RT 1S FRU1T lt gt.',
#  'RT Could someone please translate this to English I think Google is translating it wrong and I m not fluent in Spanish just.',
#  'RT Google.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'Google Photos reminding me of the 7AM Sunrise Beach View in Tisno Croatia back in 2017.',
#  'RT Depositors 150 Giveaway.',
#  '.',
#  'Hydra Gloves Emerald FT.',
#  'AK 47 The Empress WW.',
#  'M4A1 S Hyper Beast FT.',
#  '.',
#  '1 1 Ticket.',
#  'Fill the.',
#  'RT Google Pixel.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'VS ENEOS.',
#  'JABA 2023.',
#  '.',
#  '.',
#  'RT Could someone please translate this to English I think Google is translating it wrong and I m not fluent in Spanish just.',
#  'Nothing from Google on Easter Sunday Figures.',
#  'Precinct SRPREC 58372.',
#  'Orange County California.',
#  'Location on Google maps.',
#  'RT RECORD13 RADIO TIME.',
#  '.',
#  'TODAY is for MONDAY Radio Request.',
#  '.',
#  '.',
#  'iHeart Like Crazy.',
#  'It has to be an inferior or defective Google hates the alright white and makes birthday parties for the ain t right or unwanted.',
#  'RT Wazari This week nimejipanga na kwanza Nili download the app na Nika deposit to st.',
#  'gt Google.',
#  '.',
#  '.',
#  '.',
#  'gt Google.',
#  '.',
#  '.',
#  'RT.',
#  'RT The collaboration that we never expect.',
#  '.',
#  'Nasidaria X Google.',
#  '.',
#  'nangis sambil gandeng.',
#  '.',
#  'Cr yg punya tiktok.',
#  'RT YCH.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '500.',
#  '100.',
#  'pg.',
#  '.',
#  'RT VOTING THE NETIZENS REPORT.',
#  '.',
#  'TWT NETIZENSREPORT CHAEUNWOO for Most Handsome Man Alive MHMA2023 MHMA2023CHAEUN.',
#  'RT READ AND DOWNLOAD PANDORA GUYS I CANT STRESS THIS ENOUGH PLEASE link to 90 day free trial.',
#  'i suggest google translating the whole page before continuing.',
#  'the screen you see first is the booting screen not SD.',
#  'first you need a tunneling service which is usually either gradio or ngrok but i use ngrok make an ngrok account and get API key furst.',
#  'RT tcp.',
#  '.',
#  '.',
#  '.',
#  'RT Google During Hanukkah.',
#  '.',
#  'Google During Ramadan.',
#  '.',
#  'Google During Transgender Day of Visibility.',
#  '.',
#  'Google During Easter Sunday.',
#  'RT MIRAE.',
#  'DREAMROOKIE.',
#  '.',
#  '4 10 10 00AM 4 23 11 59PM KST.',
#  '.',
#  '.',
#  'RT 1.',
#  '.',
#  'PRE Solo.',
#  '.',
#  '.',
#  'KTOWN.',
#  '45.',
#  'RT Could someone please translate this to English I think Google is translating it wrong and I m not fluent in Spanish just.',
#  'RT shiki.',
#  '.',
#  'RT.',
#  'QUOPay 35.',
#  '.',
#  '.',
#  '.',
#  'shiki.',
#  'RT.',
#  '.',
#  'QUOPay1.',
#  'RT.',
#  'BAEKHYUN.',
#  '.',
#  'RT google.',
#  'RT.',
#  '.',
#  'YOONGI BTS twt.',
#  'RT.',
#  '2023.',
#  'RT.',
#  'Google Pixel Watch.',
#  'Belkin.',
#  'Logicool.',
#  '5.',
#  '.',
#  '.',
#  '.',
#  'RT PURPLEKISS.',
#  '.',
#  'lt DREAMROOKIE.',
#  'gt.',
#  '.',
#  '.',
#  '230423 23 59.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'DREAMROOKIE.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'RT Google Twitter 7.',
#  'RT Vamos a dejar un hilo largu simo con datos para charlar durante este a o con quienes est n quemados por los medios heg.',
#  '13 JUNKeeeeS.',
#  '.',
#  '.',
#  '.',
#  '154 21.',
#  '.',
#  '.',
#  '.',
#  '4 10 12.',
#  '.',
#  'Discord Google.',
#  '4.',
#  'Railway ALP Bharti 2023 238.',
#  '.',
#  'Join Telegram.',
#  '.',
#  '.',
#  'Mobile App.',
#  '.',
#  'RT Could someone please translate this to English I think Google is translating it wrong and I m not fluent in Spanish just.',
#  'noir and respectfully you shouldn t trust my analysis of history because you don t know me not sure what all that random attitude was about but you also have access to google.',
#  'RT.',
#  'VS.',
#  'JABA 2023.',
#  '.',
#  '.',
#  'RT.',
#  '.',
#  'YOONGI BTS twt.',
#  'RT hui PLS DONATE IF U CAN These funds will be used for streaming voting amp YT ads for upcoming CB U can t donate pls RT it.',
#  'RT Google cambia el logo para absolutamente todas las celebraciones pero siempre que es algo de Jes s Se quedan mudos.',
#  'RT A new court filing alleged FTX relied on Google documents Excel spreadsheets and Slack messages to manage its financial.',
#  '.',
#  'mcpa27000.',
#  'Google.',
#  '.',
#  'Google MTG.',
#  'RT 6w.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'RT BitMart X PRMX Airdrop.',
#  '234 850 000 PRMX.',
#  '.',
#  '1 Follow amp amp en.',
#  '2 Join https.',
#  'RT dragon.',
#  '.',
#  '.',
#  '.',
#  '4 23 23 59.',
#  '.',
#  '.',
#  '.',
#  'RT DM.',
#  '.',
#  '.',
#  'Maya.',
#  '.',
#  '.',
#  '.',
#  'RT chisoo4.',
#  '.',
#  'Q amp A.',
#  '4.',
#  '.',
#  '.',
#  'RT.',
#  '2023.',
#  'RT.',
#  'Google Pixel Watch.',
#  'Belkin.',
#  'Logicool.',
#  '5.',
#  '.',
#  '.',
#  '.',
#  'RT jp.',
#  '.',
#  'Love Letter.',
#  '.',
#  '.',
#  '.',
#  'jp.',
#  '.',
#  '.',
#  '.',
#  'KK.',
#  '.',
#  '1000.',
#  'google 2 100 3.',
#  'kk.',
#  'kk.',
#  'RT shiki.',
#  '3.',
#  'QUOPay 500 or 30.',
#  '.',
#  'RT.',
#  '.',
#  '.',
#  '.',
#  'shiki.',
#  'RT.',
#  '.',
#  '1.',
#  'Looked up SuccessionHBO on Google to find out the name of an actor from episode 2 and now understand what is all the hoopla is about I wish I never seen it Damn.',
#  'SUBARU VS.',
#  'JABA 2023.',
#  '.',
#  '.',
#  'RT Today s front page Monday April 10 2023.',
#  '.',
#  'Subscribe to the paper.',
#  'Read today s issue https.',
#  'RT 5 Google 2022.',
#  'Instantaneously used ChatGPT for a search today and was quite surprised Besides Wikipedia it s tough finding impactful reads on Google page index search results these days.',
#  'I wonder why Google did not put more follow up effort into Flan T5 after they showed the best SOTA open source model performance on instructional tasks Structurally T5 seems better for instructional tasks to GPT A scaled model past 20B is needed.',
#  'RT Adrian Todos recordamos el video de hace un par de a os de Patricia Bullrich borracha rodando por las escaleras con el marido.',
#  'RT Google During Hanukkah.',
#  '.',
#  'Google During Ramadan.',
#  '.',
#  'Google During Transgender Day of Visibility.',
#  '.',
#  'Google During Easter Sunday.',
#  'RT.',
#  '.',
#  'YOONGI BTS twt.',
#  'RT trends 97 Please engage with Gulf s account Like his post comment and share time to time Also please add his account in your.',
#  'RT.',
#  '.',
#  '20 000.',
#  '1.',
#  '.',
#  'PayPay Amazon iTunes Google PlayStation.',
#  '.',
#  '.',
#  'by akira.',
#  '.',
#  'You can Wiki it or Google the Satanic Church If Peter believed that the upside down cross meant being unworthy to be compared to Christ then you can see how it can be also taken as not wanting to be of Christ.',
#  'RT Ted Lieu couldn t be bothered to use Google Images to get an actual image of a child at 9 weeks.',
#  'RT 2 NCT.',
#  '.',
#  '.',
#  '4 19 23 59.',
#  '.',
#  '.',
#  '.',
#  'RT.',
#  '.',
#  '.',
#  'RT.',
#  '2023.',
#  'RT.',
#  'Google Pixel Watch.',
#  'Belkin.',
#  'Logicool.',
#  '5.',
#  '.',
#  '.',
#  '.',
#  'RT kyungsoo become hot topic in theqoo again.',
#  '.',
#  'from google translate.',
#  'May new episode kami.',
#  '.',
#  'BUDOTS TRANSCENDENT with KilBoksoon Nocebo and MurderMystery2.',
#  '.',
#  '.',
#  '.',
#  'PLEASE PAUSE on Apple Podcasts Google Podcasts Spotify.',
#  'RT boy 2023.',
#  '.',
#  '.',
#  'RT.',
#  '.',
#  '.',
#  'No idea other than banal anti christianity.',
#  '.',
#  'Google got nothing for Easter.',
#  '4 15.',
#  '.',
#  '.',
#  '.',
#  '2.',
#  '.',
#  '.',
#  '.',
#  'J viu isso aqui.',
#  '.',
#  '.',
#  'RT Baby Shark BubbleFong Friends Closed Beta Test is now available.',
#  '.',
#  'RT amp Tag 3 Friends.',
#  'Follow amp.',
#  'RT.',
#  '.',
#  'ZINE.',
#  '.',
#  'ZINE.',
#  'ZINE.',
#  '.',
#  '5 14 13 18.',
#  '.',
#  '500.',
#  '.',
#  'Lo busc en Google o realmente sabe la historia de Ecopetrol.',
#  'Google.',
#  'Crush Why do you keep asking these questions when the ANSWERS are right here.',
#  '.',
#  'MF you can do a Google search a see that you are wrong Not everything has to be a fuckin conspiracy.',
#  'VS.',
#  'JABA 2023.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'Google Pixel 6a SIM Charcoal 2438.',
#  '.',
#  'RT.',
#  '.',
#  'VTuber.',
#  '.',
#  '.',
#  '.',
#  '50000.',
#  '.',
#  '10000.',
#  'PayPay Amazon iTune.',
#  'RT Sui AIRDROP 500 000 TOCE.',
#  '.',
#  'OAT Holders will receive Airdrop from.',
#  '.',
#  'Complete the task and Claim Free OAT http.',
#  'RT shiki.',
#  '.',
#  'QUOPay 500 or 30.',
#  '.',
#  'RT.',
#  '.',
#  '.',
#  '.',
#  'shiki.',
#  'RT.',
#  '.',
#  '1.',
#  'Gmail gt.',
#  'RT.',
#  '.',
#  'YOONGI BTS twt.',
#  'RT twt iKON WORLD TOUR TICKET EVENT.',
#  ...]

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
#removing the stopwords and peroforming the lemmatization and appending back.
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
stopword = set(stopwords.words('english'))
Test_data=[]
for x in Test_X:
    tokens = word_tokenize(str(x))
    final_tokens = [w for w in tokens if w not in stopword]
    wordLemm = WordNetLemmatizer()
    finalwords=[]
    for w in final_tokens:
        if len(w)>1:
            word = wordLemm.lemmatize(w)
            finalwords.append(word)
    Test_data.append(' '.join(finalwords))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
#Removing duplicate and single word sentences.
Test_X=[]
for x in Test_data:
    if len(x)>10:
        Test_X.append(x)
Test_X = [*set(Test_X)]

# %% [markdown]
# Read the input from two separate sets that are connected to the stock sentiment into the two cells below to train the model.

# %%
twit = pd.read_csv("/content/all-data.csv", encoding = "latin-1")
Train_Y=twit["Sentiment"]
Train_X=twit["Text"]

# %%
twit = pd.read_csv("/content/stock_data.csv", encoding = "latin-1")
for ind in twit.index:
    if(twit['Sentiment'][ind]==-1):
        twit['Sentiment'][ind]="negative"
    else:
        twit['Sentiment'][ind]="positive"
# Out:
# <ipython-input-19-a2d623cb434b>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   twit['Sentiment'][ind]="positive"

# %%
Train_X=Train_X.append(twit["Text"])
Train_Y=Train_Y.append(twit["Sentiment"])
# Out:
# <ipython-input-20-57e3ec6d8e68>:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Train_X=Train_X.append(twit["Text"])
# <ipython-input-20-57e3ec6d8e68>:2: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   Train_Y=Train_Y.append(twit["Sentiment"])

# %%
Train_X.shape
# Out:
# (10637,)

# %%
#cleaned the train data by removing the stop words and doing the lemmatization
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
stopword = set(stopwords.words('english'))
Train_data=[]
for x in Train_X:
    tokens = word_tokenize(str(x))
    final_tokens = [w for w in tokens if w not in stopword]
    wordLemm = WordNetLemmatizer()
    finalwords=[]
    for w in final_tokens:
        if len(w)>1:
            word = wordLemm.lemmatize(w)
            finalwords.append(word)
    Train_data.append(' '.join(finalwords))
Train_X= Train_data
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#converted the list to Pandas data frame for analysis
df = pd.DataFrame(list(zip(Train_X, Train_Y)),
               columns =['Text', 'Sentiment'])
